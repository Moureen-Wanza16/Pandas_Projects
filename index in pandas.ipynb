# %%
import pandas as pd

# %%
df= pd.read_excel(r'Documents/Excel functions.xlsx')
df
# Out:
#    EmployeeID FirstName    LastName  Age  Gender            JobTitle  Salary  \
# 0        1001       Jim     Halpert   30    Male            Salesman   45000
# 1        1002       Pam     Beasley   30  Female        Receptionist   36000
# 2        1003    Dwight     Schrute   29    Male            Salesman   63000
# 3        1004    Angela      Martin   31  Female          Accountant   47000
# 4        1005      Toby  Flenderson   32    Male                  HR   50000
# 5        1006   Michael       Scott   35    Male    Regional Manager   65000
# 6        1007  Meredith      Palmer   32  Female  Supplier Relations   41000
# 7        1008   Stanley      Hudson   38    Male            Salesman   48000
# 8        1009     Kevin      Malone   31    Male          Accountant   42000
#
#    StartDate    EndDate                  Max                  Min
# 0 2001-11-02 2015-09-06  2003-11-08 00:00:00  1995-12-07 00:00:00
# 1 1999-10-03 2015-10-10                65000                36000
# ...

# %%
df= pd.read_excel(r'Documents/Excel functions.xlsx',index_col='FirstName')
df
# Out:
#            EmployeeID    LastName  Age  Gender            JobTitle  Salary  \
# FirstName
# Jim              1001     Halpert   30    Male            Salesman   45000
# Pam              1002     Beasley   30  Female        Receptionist   36000
# Dwight           1003     Schrute   29    Male            Salesman   63000
# Angela           1004      Martin   31  Female          Accountant   47000
# Toby             1005  Flenderson   32    Male                  HR   50000
# Michael          1006       Scott   35    Male    Regional Manager   65000
# Meredith         1007      Palmer   32  Female  Supplier Relations   41000
# Stanley          1008      Hudson   38    Male            Salesman   48000
# Kevin            1009      Malone   31    Male          Accountant   42000
#
#            StartDate    EndDate                  Max                  Min
# FirstName
# Jim       2001-11-02 2015-09-06  2003-11-08 00:00:00  1995-12-07 00:00:00
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#   FirstName  EmployeeID    LastName  Age  Gender            JobTitle  Salary  \
# 0       Jim        1001     Halpert   30    Male            Salesman   45000
# 1       Pam        1002     Beasley   30  Female        Receptionist   36000
# 2    Dwight        1003     Schrute   29    Male            Salesman   63000
# 3    Angela        1004      Martin   31  Female          Accountant   47000
# 4      Toby        1005  Flenderson   32    Male                  HR   50000
# 5   Michael        1006       Scott   35    Male    Regional Manager   65000
# 6  Meredith        1007      Palmer   32  Female  Supplier Relations   41000
# 7   Stanley        1008      Hudson   38    Male            Salesman   48000
# 8     Kevin        1009      Malone   31    Male          Accountant   42000
#
#    StartDate    EndDate                  Max                  Min
# 0 2001-11-02 2015-09-06  2003-11-08 00:00:00  1995-12-07 00:00:00
# 1 1999-10-03 2015-10-10                65000                36000
# ...

# %%
df.set_index('FirstName',inplace=True)
df
# Out:
#            EmployeeID    LastName  Age  Gender            JobTitle  Salary  \
# FirstName
# Jim              1001     Halpert   30    Male            Salesman   45000
# Pam              1002     Beasley   30  Female        Receptionist   36000
# Dwight           1003     Schrute   29    Male            Salesman   63000
# Angela           1004      Martin   31  Female          Accountant   47000
# Toby             1005  Flenderson   32    Male                  HR   50000
# Michael          1006       Scott   35    Male    Regional Manager   65000
# Meredith         1007      Palmer   32  Female  Supplier Relations   41000
# Stanley          1008      Hudson   38    Male            Salesman   48000
# Kevin            1009      Malone   31    Male          Accountant   42000
#
#            StartDate    EndDate                  Max                  Min
# FirstName
# Jim       2001-11-02 2015-09-06  2003-11-08 00:00:00  1995-12-07 00:00:00
# ...

# %%
df.loc['Pam']
# Out:
# EmployeeID                   1002
# LastName                  Beasley
# Age                            30
# Gender                     Female
# JobTitle             Receptionist
# Salary                      36000
# StartDate     1999-10-03 00:00:00
# EndDate       2015-10-10 00:00:00
# Max                         65000
# Min                         36000
# Name: Pam, dtype: object

# %%
df.iloc[1]
# Out:
# EmployeeID                   1002
# LastName                  Beasley
# Age                            30
# Gender                     Female
# JobTitle             Receptionist
# Salary                      36000
# StartDate     1999-10-03 00:00:00
# EndDate       2015-10-10 00:00:00
# Max                         65000
# Min                         36000
# Name: Pam, dtype: object

# %%
#multiindexing-multiple indexex

df.reset_index(inplace=True)
df
# Out:
#   FirstName  EmployeeID    LastName  Age  Gender            JobTitle  Salary  \
# 0       Jim        1001     Halpert   30    Male            Salesman   45000
# 1       Pam        1002     Beasley   30  Female        Receptionist   36000
# 2    Dwight        1003     Schrute   29    Male            Salesman   63000
# 3    Angela        1004      Martin   31  Female          Accountant   47000
# 4      Toby        1005  Flenderson   32    Male                  HR   50000
# 5   Michael        1006       Scott   35    Male    Regional Manager   65000
# 6  Meredith        1007      Palmer   32  Female  Supplier Relations   41000
# 7   Stanley        1008      Hudson   38    Male            Salesman   48000
# 8     Kevin        1009      Malone   31    Male          Accountant   42000
#
#    StartDate    EndDate                  Max                  Min
# 0 2001-11-02 2015-09-06  2003-11-08 00:00:00  1995-12-07 00:00:00
# 1 1999-10-03 2015-10-10                65000                36000
# ...

# %%
df.set_index(['FirstName','LastName'],inplace =True)
df
# Out:
#                       EmployeeID  Age  Gender            JobTitle  Salary  \
# FirstName LastName
# Jim       Halpert           1001   30    Male            Salesman   45000
# Pam       Beasley           1002   30  Female        Receptionist   36000
# Dwight    Schrute           1003   29    Male            Salesman   63000
# Angela    Martin            1004   31  Female          Accountant   47000
# Toby      Flenderson        1005   32    Male                  HR   50000
# Michael   Scott             1006   35    Male    Regional Manager   65000
# Meredith  Palmer            1007   32  Female  Supplier Relations   41000
# Stanley   Hudson            1008   38    Male            Salesman   48000
# Kevin     Malone            1009   31    Male          Accountant   42000
#
#                       StartDate    EndDate                  Max  \
# FirstName LastName
# Jim       Halpert    2001-11-02 2015-09-06  2003-11-08 00:00:00
# ...

# %%
df.sort_index()
# Out:
#                       EmployeeID  Age  Gender            JobTitle  Salary  \
# FirstName LastName
# Angela    Martin            1004   31  Female          Accountant   47000
# Dwight    Schrute           1003   29    Male            Salesman   63000
# Jim       Halpert           1001   30    Male            Salesman   45000
# Kevin     Malone            1009   31    Male          Accountant   42000
# Meredith  Palmer            1007   32  Female  Supplier Relations   41000
# Michael   Scott             1006   35    Male    Regional Manager   65000
# Pam       Beasley           1002   30  Female        Receptionist   36000
# Stanley   Hudson            1008   38    Male            Salesman   48000
# Toby      Flenderson        1005   32    Male                  HR   50000
#
#                       StartDate    EndDate                  Max  \
# FirstName LastName
# Angela    Martin     2000-01-05 2015-12-03                  NaN
# ...

# %%
#if rows are too many then
#pd.set_option('display.max.rows',*)
# THE * TO BE THE NUMBER OF ROWS

# %%
df.loc['Dwight','Schrute']
# Out:
# EmployeeID                   1003
# Age                            29
# Gender                       Male
# JobTitle                 Salesman
# Salary                      63000
# StartDate     2000-07-04 00:00:00
# EndDate       2017-09-08 00:00:00
# Max                           NaN
# Min                           NaN
# Name: (Dwight, Schrute), dtype: object

# %%
#USING ILOC ON MULTI INDEXING IS HARD
