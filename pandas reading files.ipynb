# %%
import pandas as pd

# %%
#pd is panda and df is data frame
#for csv file- #pd.read_csv(r'the path') or as df then df=pd.read
#without a header=pd.read_csv('rthe path',header= none)
#change header=pd.read_csv(r'path',header=none,names=['country','region']
#as df  then df=pd.read_csv(r'path')
# for text files then -pd.read_scv(r'path',sep='/t') or as table= pd.read_table(r'path',sep=',') or df=pd.read_scv(r'path',sep='/t') 
#for json files have semi function stractures-pd.read_jsonr'path') 
#for excel files- pd.read_excel(r'path')  if we have 2 sheet or more and you want a specific sheet-pd.read_excel(r'path',sheet name='sheet name')
# to see all rows where there is the ... use=pd.set_option('display ,max.rows',the number of rows) 
# to see all columns where there is the ... use=pd.set_option('display ,max.columns',the number of rows)

# %%
df= pd.read_excel(r'Documents/Tableau Full Project 1.xlsx')

# %%
df= pd.read_excel(r'Documents/Tableau Full Project 1.xlsx', sheet_name ='Listings')

# %%
df.head
# Out:
# <bound method NDFrame.head of             id                            listing_url       scrape_id  \
# 0       241032    https://www.airbnb.com/rooms/241032  20160104002432
# 1       953595    https://www.airbnb.com/rooms/953595  20160104002432
# 2      3308979   https://www.airbnb.com/rooms/3308979  20160104002432
# 3      7421966   https://www.airbnb.com/rooms/7421966  20160104002432
# 4       278830    https://www.airbnb.com/rooms/278830  20160104002432
# ...        ...                                    ...             ...
# 3813   8101950   https://www.airbnb.com/rooms/8101950  20160104002432
# 3814   8902327   https://www.airbnb.com/rooms/8902327  20160104002432
# 3815  10267360  https://www.airbnb.com/rooms/10267360  20160104002432
# 3816   9604740   https://www.airbnb.com/rooms/9604740  20160104002432
# 3817  10208623  https://www.airbnb.com/rooms/10208623  20160104002432
#
#      last_scraped                                 name  \
# ...

# %%
pd.set_option('display.max.columns',92)

# %%
df2= pd.read_excel(r'Documents/Excel functions.xlsx')

# %%
df2
# Out:
#    EmployeeID FirstName    LastName  Age  Gender            JobTitle  Salary  \
# 0        1001       Jim     Halpert   30    Male            Salesman   45000
# 1        1002       Pam     Beasley   30  Female        Receptionist   36000
# 2        1003    Dwight     Schrute   29    Male            Salesman   63000
# 3        1004    Angela      Martin   31  Female          Accountant   47000
# 4        1005      Toby  Flenderson   32    Male                  HR   50000
# 5        1006   Michael       Scott   35    Male    Regional Manager   65000
# 6        1007  Meredith      Palmer   32  Female  Supplier Relations   41000
# 7        1008   Stanley      Hudson   38    Male            Salesman   48000
# 8        1009     Kevin      Malone   31    Male          Accountant   42000
#
#    StartDate    EndDate                  Max                  Min
# 0 2001-11-02 2015-09-06  2003-11-08 00:00:00  1995-12-07 00:00:00
# 1 1999-10-03 2015-10-10                65000                36000
# ...

# %%
df3=pd.read_excel(r'Documents/Excel functions.xlsx',sheet_name ='Substitute')
df3
# Out:
#    EmployeeID FirstName    LastName  Age  Gender            JobTitle  Salary  \
# 0        1001       Jim     Halpert   30    Male            Salesman   45000
# 1        1002       Pam     Beasley   30  Female        Receptionist   36000
# 2        1003    Dwight     Schrute   29    Male            Salesman   63000
# 3        1004    Angela      Martin   31  Female          Accountant   47000
# 4        1005      Toby  Flenderson   32    Male                  HR   50000
# 5        1006   Michael       Scott   35    Male    Regional Manager   65000
# 6        1007  Meredith      Palmer   32  Female  Supplier Relations   41000
# 7        1008   Stanley      Hudson   38    Male            Salesman   48000
# 8        1009     Kevin      Malone   31    Male          Accountant   42000
#
#    StartDate     EndDate withNO instance with 1 instances with 2 instances
# 0  11/2/2001    9/6/2015       11-2-2001        11-2/2001        11/2-2001
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  9 non-null      int64
#  1   FirstName   9 non-null      object
#  2   LastName    9 non-null      object
#  3   Age         9 non-null      int64
#  4   Gender      9 non-null      object
#  5   JobTitle    9 non-null      object
#  6   Salary      9 non-null      int64
#  7   StartDate   9 non-null      datetime64[ns]
#  8   EndDate     9 non-null      datetime64[ns]
#  9   Max         2 non-null      object
#  10  Min         2 non-null      object
# dtypes: datetime64[ns](2), int64(3), object(6)
# memory usage: 924.0+ bytes

# %%
df2.shape
# Out:
# (9, 11)

# %%
df2.head()
#look at the first 5
# Out:
#    EmployeeID FirstName    LastName  Age  Gender      JobTitle  Salary  \
# 0        1001       Jim     Halpert   30    Male      Salesman   45000
# 1        1002       Pam     Beasley   30  Female  Receptionist   36000
# 2        1003    Dwight     Schrute   29    Male      Salesman   63000
# 3        1004    Angela      Martin   31  Female    Accountant   47000
# 4        1005      Toby  Flenderson   32    Male            HR   50000
#
#    StartDate    EndDate                  Max                  Min
# 0 2001-11-02 2015-09-06  2003-11-08 00:00:00  1995-12-07 00:00:00
# 1 1999-10-03 2015-10-10                65000                36000
# 2 2000-07-04 2017-09-08                  NaN                  NaN
# 3 2000-01-05 2015-12-03                  NaN                  NaN
# 4 2001-05-06 2017-08-30                  NaN                  NaN

# %%
df2.tail()
#look at the last 5
# Out:
#    EmployeeID FirstName    LastName  Age  Gender            JobTitle  Salary  \
# 4        1005      Toby  Flenderson   32    Male                  HR   50000
# 5        1006   Michael       Scott   35    Male    Regional Manager   65000
# 6        1007  Meredith      Palmer   32  Female  Supplier Relations   41000
# 7        1008   Stanley      Hudson   38    Male            Salesman   48000
# 8        1009     Kevin      Malone   31    Male          Accountant   42000
#
#    StartDate    EndDate  Max  Min
# 4 2001-05-06 2017-08-30  NaN  NaN
# 5 1995-12-07 2013-09-11  NaN  NaN
# 6 2003-11-08 2013-10-04  NaN  NaN
# 7 2002-06-09 2015-04-22  NaN  NaN
# 8 2003-08-10 2011-09-14  NaN  NaN

# %%
df2['EmployeeID']
#look at one head
# Out:
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# 4    1005
# 5    1006
# 6    1007
# 7    1008
# 8    1009
# Name: EmployeeID, dtype: int64

# %%
df2.loc[6]
# Out:
# EmployeeID                   1007
# FirstName                Meredith
# LastName                   Palmer
# Age                            32
# Gender                     Female
# JobTitle       Supplier Relations
# Salary                      41000
# StartDate     2003-11-08 00:00:00
# EndDate       2013-10-04 00:00:00
# Max                           NaN
# Min                           NaN
# Name: 6, dtype: object

# %%
df2.iloc[6]
# Out:
# EmployeeID                   1007
# FirstName                Meredith
# LastName                   Palmer
# Age                            32
# Gender                     Female
# JobTitle       Supplier Relations
# Salary                      41000
# StartDate     2003-11-08 00:00:00
# EndDate       2013-10-04 00:00:00
# Max                           NaN
# Min                           NaN
# Name: 6, dtype: object
